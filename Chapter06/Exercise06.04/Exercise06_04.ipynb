# %%
#BlackJack using Importance Sampling Monte Carlo Method 
#Off Polcy MC Prediction using Importance Sampling (Policy Evaluation)

# %%
import gym
import numpy as np
from collections import defaultdict
from functools import partial

# %%
env = gym.make('Blackjack-v0')

# %%
#creates a random policy which is a linear probability distribution
#num_Action is the number of Actions supported by the environment
def create_random_policy(num_Actions): 
    #Creates a list of size num_Actions, with a fraction 1/num_Actions. 
    #If 2 is numActions, the array value would [1/2, 1/2]
    Action = np.ones(num_Actions, dtype=float)/num_Actions
    def policy_function(observation):
        return Action
    return policy_function

# %%
#creates a greedy policy,
#sets the value of the Action at the best_possible_action, that maximizes the Q, value to be 1, rest to be 0
def create_greedy_policy(Q):
    def policy_function(state):
        #Initializing with zero the Q
        Action = np.zeros_like(Q[state], dtype = float)
        #find the index of the max Q value 
        best_possible_action = np.argmax(Q[state])
        #Assigning 1 to the best possible action
        Action[best_possible_action] = 1.0
        return Action
    return policy_function

# %%
def black_jack_importance_sampling(env, num_episodes, behaviour_policy, discount_factor  =1.0):
    
    #Initialize the value of Q
    Q = defaultdict(lambda: np.zeros(env.action_space.n))
    
    #Initialize the value of C
    C = defaultdict(lambda: np.zeros(env.action_space.n))
    
    #target policy is the greedy policy
    target_policy = create_greedy_policy(Q)
   
    for i_episode in range(1, num_episodes + 1):
        
        episode = []
        state = env.reset()
        
        #Generate an episode following behaviour policy b: So, Ao, R1,...,ST-1, AT-1, RT
        for i in range(100):
            
            probability = behaviour_policy(state)
            action = np.random.choice(np.arange(len(probability)), p=probability)
            next_state, reward, done, info = env.step(action)
            episode.append((state, action, reward))
            
            if done:
                break
            state = next_state
        
        # G <- 0
        G = 0.0   
        
        # W <- 0
        W = 1.0     
        
        #Loop for each step of episode t=T-1, T-2,...,0 while W != 0
        for step in range(len(episode))[::-1]:
            state, action, reward = episode[step]
            
            #G <- gamma * G + Rt+1
            G = discount_factor * G + reward    
            
            # C(St, At) = C(St, At) + W
            C[state][action] += W
            
            #Q (St, At) <- Q (St, At) + W / C (St, At)
            Q[state][action] += (W / C[state][action]) * (G - Q[state][action])
            
            #If action not equal to argmax of target policy proceed to next episode
            if action != np.argmax(target_policy(state)):
                break
            # W <- W * Pi(At/St) / b(At/St)
            W = W * 1./behaviour_policy(state)[action]

    return Q, target_policy

# %%
#create random policy
random_policy = create_random_policy(env.action_space.n)
#using importance sampling evaluates the target policy by learning from the behaviour policy
Q, policy =  black_jack_importance_sampling(env, 50000, random_policy)

# %%
valuefunction = defaultdict(float)
for state, action_values in Q.items():
    action_value = np.max(action_values)
    valuefunction[state] = action_value
    print("state is", state, "value is", valuefunction[state])
# Out:
# state is (21, 2, False) value is 0.9043478260869562
# state is (12, 2, False) value is -0.25263157894736843
# state is (19, 2, True) value is 0.3846153846153846
# state is (20, 1, False) value is 0.07167235494880556
# state is (18, 5, False) value is 0.1361256544502617
# state is (14, 5, False) value is -0.09452736318407957
# state is (12, 5, False) value is -0.06214689265536725
# state is (17, 1, False) value is -0.5369458128078817
# state is (19, 5, False) value is 0.4191616766467066
# state is (13, 5, False) value is -0.15454545454545454
# state is (20, 10, False) value is 0.453049370764763
# state is (17, 6, False) value is -0.06060606060606062
# state is (14, 7, False) value is -0.2565445026178012
# state is (11, 9, False) value is 0.26785714285714296
# state is (15, 3, False) value is -0.2972972972972972
# state is (8, 7, False) value is 0.28571428571428575
# state is (11, 3, False) value is 0.29787234042553185
# state is (19, 4, False) value is 0.4595959595959597
# state is (21, 10, False) value is 0.8541666666666662
# state is (19, 10, False) value is -0.016620498614958432
# state is (9, 10, False) value is -0.26896551724137935
# state is (12, 10, False) value is -0.4582338902147968
# state is (5, 10, False) value is -0.33333333333333326
# state is (14, 10, False) value is -0.5414507772020726
# state is (8, 5, False) value is 6.938893903907228e-18
# state is (15, 7, False) value is -0.3216374269005849
# state is (16, 10, False) value is -0.5473833097595476
# state is (13, 9, False) value is -0.42156862745098034
# state is (21, 7, False) value is 0.9354838709677418
# state is (20, 2, False) value is 0.6708333333333334
# state is (16, 2, False) value is -0.2999999999999999
# state is (15, 6, False) value is -0.14583333333333331
# state is (21, 9, True) value is 0.9504950495049505
# state is (20, 9, True) value is 0.7575757575757576
# state is (20, 3, False) value is 0.6947791164658633
# state is (17, 2, False) value is -0.11235955056179761
# state is (9, 4, False) value is 0.44000000000000006
# state is (19, 8, False) value is 0.6723163841807906
# state is (19, 2, False) value is 0.47305389221556887
# state is (16, 3, False) value is -0.2117647058823529
# state is (18, 1, False) value is -0.2464454976303316
# state is (15, 5, False) value is -0.04046242774566476
# state is (21, 5, False) value is 0.8809523809523812
# state is (16, 5, False) value is -0.22891566265060243
# state is (18, 10, True) value is -0.038461538461538464
# state is (13, 7, False) value is -0.2717391304347827
# state is (13, 10, True) value is -0.15217391304347827
# state is (19, 3, False) value is 0.49375000000000013
# state is (20, 6, False) value is 0.6899224806201554
# state is (19, 6, False) value is 0.4201183431952663
# state is (18, 2, False) value is 0.06918238993710692
# state is (7, 10, False) value is -0.368421052631579
# state is (7, 1, False) value is -0.4634146341463414
# state is (18, 4, False) value is 0.17514124293785316
# state is (12, 4, False) value is -0.103448275862069
# state is (11, 6, False) value is 0.42105263157894735
# state is (9, 7, False) value is 0.36170212765957455
# state is (18, 10, False) value is -0.18879999999999994
# state is (21, 8, False) value is 0.9340659340659339
# state is (11, 8, False) value is 0.42857142857142855
# state is (17, 5, False) value is 0.023668639053254455
# state is (20, 4, False) value is 0.6639004149377596
# state is (21, 4, True) value is 0.8715596330275229
# state is (4, 10, False) value is -0.44
# state is (12, 1, False) value is -0.6382978723404255
# state is (17, 3, False) value is -0.23863636363636365
# state is (21, 10, True) value is 0.9070351758793969
# state is (21, 6, True) value is 0.899082568807339
# state is (14, 8, False) value is -0.3177570093457945
# state is (20, 8, True) value is 1.0
# state is (16, 8, False) value is -0.5323383084577114
# state is (18, 3, True) value is 0.0882352941176471
# state is (15, 3, True) value is 0.23076923076923078
# state is (20, 7, False) value is 0.8370044052863436
# state is (15, 7, True) value is 0.13043478260869568
# state is (15, 10, False) value is -0.4836272040302264
# state is (12, 7, False) value is -0.1441441441441442
# state is (7, 4, False) value is 0.0
# state is (16, 7, False) value is -0.4153846153846158
# state is (21, 2, True) value is 0.8499999999999999
# state is (13, 5, True) value is 0.45454545454545453
# state is (17, 6, True) value is -5.551115123125783e-17
# state is (19, 9, False) value is 0.17857142857142863
# state is (16, 4, False) value is -0.005347593582887726
# state is (12, 6, True) value is 1.0
# state is (18, 8, False) value is -2.862293735361732e-17
# state is (13, 10, False) value is -0.47098515519568157
# state is (21, 1, False) value is 0.673267326732673
# state is (17, 10, False) value is -0.4217207334273628
# state is (16, 9, False) value is -0.5422885572139301
# state is (18, 9, False) value is -0.12738853503184716
# state is (15, 9, False) value is -0.39175257731958757
# state is (13, 2, False) value is -0.2372093023255814
# state is (14, 6, False) value is 0.005405405405405392
# state is (18, 6, False) value is 0.312849162011173
# state is (12, 6, False) value is -0.1442307692307692
# state is (21, 3, False) value is 0.9166666666666664
# state is (9, 8, False) value is 2.0321046432871167e-17
# state is (16, 1, True) value is -0.11111111111111108
# state is (11, 10, False) value is 0.1442786069651741
# state is (14, 2, False) value is -0.3212669683257917
# state is (12, 8, False) value is -0.3073170731707319
# state is (14, 9, False) value is -0.42990654205607465
# state is (10, 10, False) value is -0.15540540540540537
# state is (13, 4, False) value is -0.16000000000000003
# state is (21, 9, False) value is 0.8878504672897193
# state is (20, 9, False) value is 0.6641791044776117
# state is (10, 9, False) value is 0.14285714285714282
# state is (14, 3, False) value is -0.24882629107981227
# state is (9, 9, False) value is -0.21052631578947364
# state is (10, 6, False) value is 0.2
# state is (16, 10, True) value is -0.3
# state is (7, 2, False) value is -0.07142857142857144
# state is (18, 7, False) value is 0.36548223350253817
# state is (15, 2, False) value is -0.2727272727272727
# state is (10, 5, False) value is 0.0392156862745098
# state is (17, 4, False) value is -0.08536585365853658
# state is (14, 4, False) value is -0.22105263157894742
# state is (13, 1, False) value is -0.60427807486631
# state is (11, 4, False) value is 0.10204081632653063
# state is (10, 1, False) value is -0.3000000000000001
# state is (15, 4, False) value is -0.22705314009661837
# state is (21, 4, False) value is 0.9065420560747663
# state is (8, 1, False) value is -0.18518518518518523
# state is (18, 3, False) value is 0.10937500000000003
# state is (8, 3, False) value is -4.163336342344337e-17
# state is (9, 2, False) value is 0.3076923076923077
# state is (6, 10, False) value is -0.3214285714285714
# state is (19, 7, False) value is 0.5279503105590064
# state is (15, 1, False) value is -0.5916230366492146
# state is (12, 3, False) value is -0.20603015075376882
# state is (21, 1, True) value is 0.5454545454545453
# state is (19, 10, True) value is -0.04545454545454547
# state is (13, 3, False) value is -0.3232323232323233
# state is (13, 9, True) value is 0.5833333333333333
# state is (12, 9, False) value is -0.4719101123595507
# state is (20, 5, False) value is 0.6153846153846156
# state is (17, 8, True) value is -0.2142857142857143
# state is (17, 8, False) value is -0.39523809523809517
# state is (21, 6, False) value is 0.9255319148936169
# state is (13, 6, False) value is -0.10227272727272718
# state is (8, 8, False) value is -0.11764705882352941
# state is (15, 8, False) value is -0.5023041474654377
# state is (21, 7, True) value is 0.9292035398230089
# state is (16, 1, False) value is -0.5902439024390248
# state is (15, 6, True) value is 0.2857142857142857
# state is (4, 7, False) value is -0.5999999999999999
# state is (19, 4, True) value is 0.42857142857142877
# state is (17, 9, False) value is -0.4010989010989011
# state is (14, 10, True) value is -0.5102040816326531
# state is (20, 10, True) value is 0.5163934426229504
# state is (18, 9, True) value is -0.06249999999999997
# state is (21, 3, True) value is 0.8900000000000001
# state is (5, 8, False) value is -5.551115123125783e-17
# state is (9, 6, False) value is 0.16666666666666666
# state is (10, 2, False) value is 0.2448979591836734
# state is (16, 6, False) value is -0.20603015075376874
# state is (12, 9, True) value is 1.0
# state is (20, 5, True) value is 0.5714285714285715
# state is (12, 5, True) value is 0.375
# state is (8, 10, False) value is -0.22950819672131156
# state is (15, 4, True) value is 0.25
# state is (6, 9, False) value is -0.3333333333333333
# state is (18, 4, True) value is 0.18181818181818182
# state is (12, 10, True) value is -0.5102040816326531
# state is (4, 2, False) value is 0.75
# state is (21, 8, True) value is 0.9074074074074072
# state is (11, 1, False) value is -0.06756756756756759
# state is (15, 1, True) value is -0.5384615384615384
# state is (5, 4, False) value is -0.2592592592592592
# state is (10, 3, False) value is 0.11538461538461542
# state is (7, 8, False) value is -0.1379310344827586
# state is (9, 1, False) value is -0.4838709677419355
# state is (17, 7, False) value is -0.14124293785310746
# state is (12, 3, True) value is 0.20000000000000007
# state is (20, 8, False) value is 0.8364312267657994
# state is (6, 2, False) value is -0.27777777777777773
# state is (11, 5, False) value is 0.48936170212765956
# state is (14, 9, True) value is -0.0769230769230769
# state is (17, 2, True) value is -0.06896551724137928
# state is (9, 5, False) value is -0.058823529411764705
# state is (20, 4, True) value is 0.6764705882352939
# state is (13, 8, False) value is -0.2520325203252032
# state is (7, 9, False) value is -0.19999999999999998
# state is (14, 7, True) value is -0.06666666666666667
# state is (6, 3, False) value is 0.1428571428571428
# state is (16, 4, True) value is -0.13043478260869565
# state is (5, 2, False) value is -0.28571428571428564
# state is (5, 7, False) value is -0.1111111111111111
# state is (20, 6, True) value is 0.7837837837837837
# state is (4, 4, False) value is -0.29411764705882354
# state is (8, 6, False) value is 0.07407407407407406
# state is (19, 1, False) value is -0.15976331360946744
# state is (10, 7, False) value is 0.32653061224489793
# state is (14, 1, False) value is -0.6084656084656079
# state is (13, 8, True) value is -0.17647058823529416
# state is (13, 6, True) value is 1.0
# state is (17, 10, True) value is -0.12000000000000005
# state is (10, 8, False) value is 0.4117647058823529
# state is (18, 7, True) value is 0.5483870967741935
# state is (14, 5, True) value is 0.7142857142857143
# state is (5, 3, False) value is -0.4074074074074074
# state is (6, 4, False) value is -0.27777777777777773
# state is (11, 7, False) value is 0.40983606557377034
# state is (8, 4, False) value is 0.14285714285714285
# state is (18, 1, True) value is -0.2857142857142857
# state is (21, 5, True) value is 0.865546218487395
# state is (17, 3, True) value is -1.3344026738283132e-17
# state is (9, 3, False) value is -0.10714285714285714
# state is (19, 8, True) value is 0.4545454545454545
# state is (16, 2, True) value is 0.4545454545454545
# state is (19, 6, True) value is 0.5789473684210527
# state is (6, 7, False) value is -0.29411764705882354
# state is (19, 3, True) value is 0.39999999999999997
# state is (15, 10, True) value is -0.1904761904761905
# state is (15, 9, True) value is -0.5
# state is (16, 8, True) value is -0.06666666666666661
# state is (14, 2, True) value is 0.14285714285714288
# state is (14, 4, True) value is 0.14285714285714282
# state is (20, 1, True) value is 0.35135135135135137
# state is (16, 3, True) value is 0.33333333333333337
# state is (19, 1, True) value is -0.3333333333333333
# state is (7, 3, False) value is -0.39285714285714285
# state is (8, 9, False) value is -0.1935483870967742
# state is (13, 4, True) value is -0.14285714285714285
# state is (10, 4, False) value is 0.3243243243243243
# state is (7, 7, False) value is 0.0
# state is (19, 9, True) value is 0.12499999999999997
# state is (18, 6, True) value is 0.2727272727272727
# state is (17, 4, True) value is 0.06666666666666665
# state is (18, 2, True) value is 0.125
# state is (13, 2, True) value is -0.16666666666666666
# state is (19, 5, True) value is 0.6216216216216215
# state is (13, 7, True) value is -0.28571428571428575
# state is (17, 7, True) value is -0.029411764705882366
# state is (15, 2, True) value is 0.1428571428571429
# state is (4, 9, False) value is -0.2727272727272727
# state is (6, 1, False) value is -4.163336342344337e-17
# state is (17, 1, True) value is -0.5172413793103449
# state is (14, 1, True) value is 0.18749999999999994
# state is (12, 1, True) value is 0.3333333333333333
# state is (14, 6, True) value is 0.10526315789473678
# state is (11, 2, False) value is 0.29411764705882343
# state is (16, 5, True) value is 0.6666666666666667
# state is (13, 3, True) value is 0.4285714285714286
# state is (18, 5, True) value is 0.17647058823529416
# state is (4, 8, False) value is 0.1428571428571428
# state is (17, 9, True) value is 0.0952380952380952
# state is (15, 5, True) value is 0.7222222222222223
# state is (6, 6, False) value is 0.33333333333333337
# state is (7, 5, False) value is 0.0
# state is (16, 7, True) value is 2.7755575615628914e-17
# state is (17, 5, True) value is 0.2
# state is (20, 2, True) value is 0.7
# state is (5, 1, False) value is -1.0
# state is (14, 3, True) value is 0.3200000000000001
# state is (16, 9, True) value is -0.5
# state is (18, 8, True) value is 0.16666666666666666
# state is (20, 7, True) value is 0.9130434782608694
# state is (8, 2, False) value is 0.21428571428571433
# state is (6, 8, False) value is 0.5555555555555556
# state is (5, 6, False) value is -0.09999999999999995
# state is (7, 6, False) value is 0.23076923076923073
# state is (6, 5, False) value is 0.11111111111111112
# state is (5, 5, False) value is 0.1428571428571428
# state is (19, 7, True) value is 0.5882352941176471
# state is (12, 8, True) value is 0.0
# state is (4, 3, False) value is 0.0
# state is (20, 3, True) value is 0.75
# state is (14, 8, True) value is 0.31034482758620696
# state is (13, 1, True) value is -0.29999999999999993
# state is (16, 6, True) value is 0.15384615384615388
# state is (12, 7, True) value is 1.0
# state is (4, 5, False) value is 0.11111111111111105
# state is (4, 6, False) value is 0.1428571428571428
# state is (4, 1, False) value is 1.0
# state is (15, 8, True) value is -0.5
# state is (12, 4, True) value is 0.5
# state is (5, 9, False) value is 0.23076923076923078
# state is (12, 2, True) value is 0.4285714285714286
