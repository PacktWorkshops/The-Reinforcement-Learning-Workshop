# %%
#BlackJack using Importance Sampling Monte Carlo Method 
#Off Polcy MC Prediction using Importance Sampling (Policy Evaluation)

# %%
import gym
import numpy as np
from collections import defaultdict
from functools import partial

# %%
env = gym.make('Blackjack-v0')

# %%
#creates a random policy which is a linear probability distribution
#num_Action is the number of Actions supported by the enviornment
def create_random_policy(num_Actions): 
    #Creates a list of size num_Actions, with a fraction 1/num_Actions. 
    #If 2 is numActions, the array value would [1/2, 1/2]
    Action = np.ones(num_Actions, dtype=float)/num_Actions
    def policy_function(observation):
        return Action
    return policy_function

# %%
#creates a greedy policy,
#sets the valye of the Action at the best_possible_action, that maximizes the Q, value to be 1, rest to be 0
def create_greedy_policy(Q):
    def policy_function(state):
        #Initializing with zero the Q
        Action = np.zeros_like(Q[state], dtype = float)
        #find the index of the max Q value 
        best_possible_action = np.argmax(Q[state])
        #Assigning 1 to the best possible action
        Action[best_possible_action] = 1.0
        return Action
    return policy_function

# %%
def black_jack_importance_sampling(env, num_episodes, behaviour_policy, discount_factor  =1.0):
    
    #Initialize the value of Q
    Q = defaultdict(lambda: np.zeros(env.action_space.n))
    
    #Initialize the value of C
    C = defaultdict(lambda: np.zeros(env.action_space.n))
    
    #target policy is the greedy policy
    target_policy = create_greedy_policy(Q)
   
    for i_episode in range(1, num_episodes + 1):
        
        episode = []
        state = env.reset()
        
        #Generate an episode following behaviour policy b: So, Ao, R1,...,ST-1, AT-1, RT
        for i in range(100):
            
            probability = behaviour_policy(state)
            action = np.random.choice(np.arange(len(probability)), p=probability)
            next_state, reward, done, info = env.step(action)
            episode.append((state, action, reward))
            
            if done:
                break
            state = next_state
        
        # G <- 0
        G = 0.0   
        
        # W <- 0
        W = 1.0     
        
        #Loop for each step of episode t=T-1, T-2,...,0 while W != 0
        for step in range(len(episode))[::-1]:
            state, action, reward = episode[step]
            
            #G <- gamma * G + Rt+1
            G = discount_factor * G + reward    
            
            # C(St, At) = C(St, At) + W
            C[state][action] += W
            
            #Q (St, At) <- Q (St, At) + W / C (St, At)
            Q[state][action] += (W / C[state][action]) * (G - Q[state][action])
            
            if action != np.argmax(target_policy(state)):
                break
            # W <- W * Pi(At/St) / b(At/St)
            W = W * 1./behaviour_policy(state)[action]

    return Q, target_policy

# %%
#create random policy
random_policy = create_random_policy(env.action_space.n)
Q, policy =  black_jack_importance_sampling(env, 50000, random_policy)

# %%
valuefunction = defaultdict(float)
for state, action_values in Q.items():
    action_value = np.max(action_values)
    valuefunction[state] = action_value
    print("state is", state, "value is", valuefunction[state])
# Out:
# state is (15, 4, False) value is -0.21126760563380273
# state is (15, 3, False) value is -0.255813953488372
# state is (21, 10, True) value is 0.8865248226950363
# state is (14, 10, False) value is -0.5018226002430137
# state is (12, 9, False) value is -0.2372093023255813
# state is (14, 5, False) value is -0.1188118811881188
# state is (21, 5, True) value is 0.9400000000000003
# state is (18, 8, True) value is 0.18750000000000003
# state is (15, 9, False) value is -0.4207650273224042
# state is (12, 10, False) value is -0.4254278728606358
# state is (20, 7, False) value is 0.78740157480315
# state is (7, 2, False) value is -0.23076923076923073
# state is (19, 6, False) value is 0.5000000000000004
# state is (5, 8, False) value is 0.19999999999999996
# state is (6, 10, False) value is -0.5645161290322581
# state is (9, 8, False) value is -0.3
# state is (10, 8, False) value is 0.5714285714285714
# state is (21, 1, False) value is 0.6666666666666664
# state is (16, 1, False) value is -0.5477386934673364
# state is (21, 10, False) value is 0.8878281622911693
# state is (12, 2, False) value is -0.2975609756097563
# state is (19, 9, False) value is 0.19444444444444448
# state is (18, 1, False) value is -0.4078212290502792
# state is (21, 3, False) value is 0.8290598290598288
# state is (11, 3, False) value is 0.2692307692307693
# state is (16, 9, False) value is -0.48148148148148173
# state is (21, 9, True) value is 0.9603960396039606
# state is (14, 4, False) value is -0.32323232323232315
# state is (21, 8, False) value is 0.8932038834951453
# state is (17, 8, False) value is -0.33507853403141374
# state is (6, 9, False) value is -0.12000000000000001
# state is (13, 9, False) value is -0.46268656716417894
# state is (20, 10, False) value is 0.43703007518796977
# state is (15, 10, False) value is -0.5330836454431956
# state is (17, 10, False) value is -0.4824046920821111
# state is (18, 2, False) value is 0.14594594594594593
# state is (13, 7, False) value is -0.08571428571428574
# state is (14, 1, False) value is -0.7319587628865982
# state is (13, 2, False) value is -0.28342245989304815
# state is (8, 10, False) value is -0.1484375000000001
# state is (15, 5, False) value is -0.06341463414634144
# state is (8, 8, False) value is -0.31034482758620696
# state is (12, 4, False) value is -0.17766497461928943
# state is (16, 4, False) value is -0.11004784688995217
# state is (20, 6, False) value is 0.7376425855513309
# state is (20, 6, True) value is 0.75
# state is (13, 10, False) value is -0.49009247027741076
# state is (21, 6, False) value is 0.8803418803418803
# state is (21, 6, True) value is 0.88
# state is (19, 10, False) value is -0.02351097178683382
# state is (15, 2, False) value is -0.28
# state is (17, 3, False) value is -0.060109289617486315
# state is (17, 1, False) value is -0.6269430051813474
# state is (15, 8, False) value is -0.3535353535353534
# state is (18, 10, False) value is -0.2991573033707862
# state is (20, 2, False) value is 0.6840148698884762
# state is (17, 9, True) value is -0.11111111111111108
# state is (16, 9, True) value is -3.784851220313034e-17
# state is (14, 6, False) value is -0.07964601769911504
# state is (14, 2, False) value is -0.2842105263157893
# state is (9, 10, False) value is -0.19333333333333327
# state is (10, 6, False) value is 0.2898550724637681
# state is (8, 6, False) value is 0.07894736842105265
# state is (21, 9, False) value is 0.8725490196078431
# state is (13, 3, False) value is -0.1921182266009853
# state is (11, 10, False) value is 0.009174311926605493
# state is (19, 2, False) value is 0.3642384105960265
# state is (18, 10, True) value is -0.20338983050847445
# state is (18, 6, True) value is 0.0869565217391304
# state is (20, 4, False) value is 0.7224334600760456
# state is (18, 9, False) value is -0.21195652173913057
# state is (19, 8, False) value is 0.5027624309392269
# state is (13, 8, False) value is -0.2710280373831776
# state is (12, 3, False) value is -0.20792079207920783
# state is (10, 3, False) value is 0.13043478260869565
# state is (18, 7, False) value is 0.4242424242424242
# state is (12, 7, False) value is -0.15121951219512195
# state is (21, 1, True) value is 0.7029702970297029
# state is (18, 3, False) value is 0.24338624338624315
# state is (13, 5, False) value is -0.18222222222222204
# state is (19, 1, False) value is -0.08522727272727272
# state is (9, 1, False) value is -0.1923076923076923
# state is (16, 2, False) value is -0.2698412698412698
# state is (17, 6, False) value is -0.01685393258426965
# state is (20, 1, True) value is 6.938893903907228e-18
# state is (13, 1, False) value is -0.4564102564102564
# state is (19, 3, False) value is 0.4779874213836478
# state is (20, 5, True) value is 0.6764705882352942
# state is (20, 9, True) value is 0.641025641025641
# state is (21, 7, False) value is 0.8799999999999999
# state is (21, 7, True) value is 0.9278350515463919
# state is (19, 10, True) value is 0.05426356589147288
# state is (9, 7, False) value is 0.24242424242424243
# state is (10, 10, False) value is 6.071532165918825e-18
# state is (16, 10, False) value is -0.5743519781718964
# state is (14, 6, True) value is 0.07692307692307696
# state is (13, 10, True) value is 1.3877787807814457e-17
# state is (9, 6, False) value is 0.32499999999999996
# state is (18, 5, False) value is 0.262135922330097
# state is (12, 10, True) value is -0.41935483870967755
# state is (20, 2, True) value is 0.8000000000000002
# state is (6, 8, False) value is 0.07999999999999989
# state is (20, 5, False) value is 0.6879194630872483
# state is (19, 4, False) value is 0.48000000000000004
# state is (17, 7, False) value is 0.01204819277108432
# state is (17, 7, True) value is -0.2105263157894737
# state is (8, 1, False) value is -0.3749999999999999
# state is (18, 5, True) value is 0.482758620689655
# state is (19, 8, True) value is 0.46428571428571425
# state is (15, 8, True) value is 0.05882352941176475
# state is (20, 3, False) value is 0.7083333333333333
# state is (10, 2, False) value is 0.1515151515151515
# state is (14, 3, False) value is -0.34715025906735736
# state is (17, 9, False) value is -0.4611111111111109
# state is (18, 4, False) value is 0.0584795321637427
# state is (12, 6, False) value is -0.007874015748031468
# state is (16, 8, False) value is -0.47252747252747246
# state is (12, 8, False) value is -0.22869955156950678
# state is (8, 2, False) value is 0.30769230769230776
# state is (7, 6, False) value is 0.1538461538461538
# state is (13, 4, False) value is -0.24242424242424238
# state is (14, 9, False) value is -0.44347826086956527
# state is (12, 1, False) value is -0.33628318584070793
# state is (20, 9, False) value is 0.7912087912087912
# state is (14, 8, False) value is -0.4273504273504275
# state is (17, 5, False) value is 0.012500000000000015
# state is (21, 4, False) value is 0.9166666666666667
# state is (10, 4, False) value is 0.2564102564102565
# state is (12, 5, False) value is -0.07070707070707069
# state is (21, 4, True) value is 0.857142857142857
# state is (20, 1, False) value is 0.03731343283582092
# state is (13, 7, True) value is -0.09090909090909094
# state is (9, 2, False) value is -0.25
# state is (21, 3, True) value is 0.8717948717948717
# state is (15, 3, True) value is 0.33333333333333337
# state is (20, 8, False) value is 0.7272727272727272
# state is (9, 4, False) value is 0.18749999999999997
# state is (16, 3, False) value is -0.30964467005076135
# state is (18, 6, False) value is 0.13407821229050285
# state is (8, 7, False) value is 0.14705882352941174
# state is (18, 4, True) value is -0.2666666666666666
# state is (21, 2, False) value is 0.9130434782608696
# state is (6, 7, False) value is 0.05882352941176465
# state is (21, 5, False) value is 0.8899999999999997
# state is (11, 7, False) value is 0.04545454545454542
# state is (9, 3, False) value is 0.14705882352941183
# state is (15, 1, False) value is -0.550802139037433
# state is (7, 10, False) value is -0.3736263736263738
# state is (20, 10, True) value is 0.434108527131783
# state is (8, 5, False) value is 0.3333333333333333
# state is (16, 4, True) value is 0.23076923076923073
# state is (19, 1, True) value is -2.7755575615628914e-17
# state is (11, 9, False) value is 0.38636363636363624
# state is (16, 10, True) value is -0.25000000000000006
# state is (11, 4, False) value is 0.10000000000000003
# state is (17, 10, True) value is -0.02173913043478263
# state is (18, 8, False) value is 0.13496932515337426
# state is (21, 2, True) value is 0.8829787234042555
# state is (15, 1, True) value is -0.5
# state is (10, 7, False) value is 0.5576923076923077
# state is (16, 1, True) value is -0.2
# state is (13, 9, True) value is 0.28571428571428564
# state is (11, 1, False) value is -0.26086956521739124
# state is (10, 1, False) value is -0.1509433962264151
# state is (15, 7, False) value is -0.2459016393442624
# state is (16, 6, False) value is -0.2254901960784313
# state is (6, 6, False) value is 0.36
# state is (17, 2, False) value is 0.05660377358490565
# state is (8, 3, False) value is 0.16666666666666666
# state is (17, 4, False) value is -0.2324324324324325
# state is (15, 9, True) value is -0.2857142857142857
# state is (7, 3, False) value is -0.23404255319148934
# state is (13, 6, False) value is -0.2670157068062827
# state is (19, 3, True) value is 0.5
# state is (9, 9, False) value is 0.08695652173913049
# state is (4, 5, False) value is 0.20000000000000007
# state is (11, 8, False) value is 0.26530612244897955
# state is (16, 7, False) value is -0.311111111111111
# state is (11, 2, False) value is 0.36956521739130427
# state is (12, 1, True) value is 1.0
# state is (15, 7, True) value is 0.5
# state is (18, 3, True) value is 0.25
# state is (17, 1, True) value is -0.33333333333333337
# state is (14, 5, True) value is 0.22222222222222218
# state is (5, 1, False) value is -0.8571428571428571
# state is (14, 7, False) value is -0.30337078651685395
# state is (15, 10, True) value is -0.018867924528301876
# state is (14, 9, True) value is 0.4
# state is (15, 6, False) value is -0.18181818181818188
# state is (18, 2, True) value is 0.15789473684210523
# state is (14, 1, True) value is 0.0
# state is (19, 7, False) value is 0.7105263157894739
# state is (11, 6, False) value is 0.2916666666666668
# state is (19, 7, True) value is 0.6829268292682925
# state is (16, 5, False) value is -0.22619047619047625
# state is (8, 4, False) value is 0.125
# state is (12, 2, True) value is 0.19999999999999998
# state is (16, 7, True) value is 0.6
# state is (20, 4, True) value is 0.6666666666666665
# state is (19, 5, True) value is 0.6666666666666666
# state is (13, 5, True) value is 0.46153846153846156
# state is (21, 8, True) value is 0.9181818181818183
# state is (7, 8, False) value is -0.08695652173913042
# state is (14, 3, True) value is 0.3333333333333333
# state is (11, 5, False) value is 0.5208333333333334
# state is (17, 8, True) value is 0.23076923076923078
# state is (20, 7, True) value is 0.6296296296296297
# state is (5, 6, False) value is 5.551115123125783e-17
# state is (6, 4, False) value is -0.1515151515151515
# state is (19, 5, False) value is 0.5220125786163524
# state is (4, 2, False) value is -0.42857142857142855
# state is (18, 1, True) value is -0.3636363636363636
# state is (17, 5, True) value is 0.30769230769230765
# state is (10, 5, False) value is 0.2444444444444444
# state is (5, 10, False) value is -0.31999999999999995
# state is (19, 6, True) value is 0.3235294117647059
# state is (15, 4, True) value is 0.6666666666666665
# state is (6, 2, False) value is 0.0434782608695652
# state is (14, 10, True) value is -0.08064516129032254
# state is (14, 2, True) value is 0.19999999999999996
# state is (14, 7, True) value is 0.5
# state is (15, 2, True) value is 0.2352941176470588
# state is (7, 1, False) value is -0.6470588235294117
# state is (13, 8, True) value is -0.33333333333333326
# state is (4, 10, False) value is -0.09090909090909086
# state is (16, 6, True) value is 0.06250000000000003
# state is (4, 6, False) value is 0.5555555555555556
# state is (16, 8, True) value is -0.37500000000000006
# state is (13, 6, True) value is 0.24999999999999994
# state is (17, 3, True) value is 0.3125
# state is (7, 7, False) value is -0.03703703703703704
# state is (9, 5, False) value is 0.2903225806451613
# state is (7, 9, False) value is -0.26086956521739135
# state is (19, 4, True) value is 0.7272727272727272
# state is (7, 4, False) value is -0.14814814814814817
# state is (13, 1, True) value is -0.25000000000000006
# state is (20, 3, True) value is 0.7666666666666666
# state is (12, 8, True) value is 0.0
# state is (13, 3, True) value is 0.625
# state is (6, 3, False) value is -0.08108108108108107
# state is (19, 2, True) value is 0.411764705882353
# state is (17, 4, True) value is -1.0408340855860843e-17
# state is (6, 1, False) value is -0.6
# state is (6, 5, False) value is 0.11111111111111112
# state is (5, 5, False) value is 0.13043478260869565
# state is (16, 3, True) value is 2.7755575615628914e-17
# state is (12, 4, True) value is 0.3846153846153846
# state is (12, 5, True) value is 1.0
# state is (10, 9, False) value is 0.09999999999999999
# state is (17, 2, True) value is 4.163336342344337e-17
# state is (14, 8, True) value is 0.0
# state is (12, 6, True) value is 0.3846153846153846
# state is (18, 9, True) value is 0.15151515151515152
# state is (19, 9, True) value is 0.55
# state is (4, 1, False) value is -0.8461538461538461
# state is (18, 7, True) value is 0.5
# state is (8, 9, False) value is -0.37499999999999994
# state is (16, 5, True) value is 0.4
# state is (13, 2, True) value is 0.19999999999999998
# state is (14, 4, True) value is -1.3877787807814457e-17
# state is (17, 6, True) value is -0.03571428571428572
# state is (20, 8, True) value is 0.5454545454545455
# state is (4, 8, False) value is 0.3333333333333333
# state is (5, 7, False) value is -0.45454545454545453
# state is (12, 7, True) value is 0.0
# state is (16, 2, True) value is -4.163336342344337e-17
# state is (12, 9, True) value is -0.5384615384615383
# state is (5, 2, False) value is -0.09090909090909093
# state is (5, 3, False) value is -0.2727272727272727
# state is (12, 3, True) value is 0.0
# state is (5, 9, False) value is -0.24137931034482757
# state is (13, 4, True) value is 0.2380952380952381
# state is (15, 5, True) value is 0.5499999999999999
# state is (15, 6, True) value is -0.1428571428571429
# state is (4, 3, False) value is 0.24999999999999997
# state is (7, 5, False) value is 0.21052631578947367
# state is (4, 7, False) value is 0.0
# state is (5, 4, False) value is 0.625
# state is (4, 4, False) value is -0.6000000000000001
# state is (4, 9, False) value is -0.4285714285714286
