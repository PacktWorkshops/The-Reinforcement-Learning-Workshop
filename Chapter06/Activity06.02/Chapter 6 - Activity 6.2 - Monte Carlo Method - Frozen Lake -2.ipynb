# %%
import gym
import numpy as np

# %%
#Setting up the Frozen Lake environment
env = gym.make("FrozenLake-v0", is_slippery=False)

# %%
#Initializing the Q and num_state_action
Q = np.zeros([env.observation_space.n, env.action_space.n])
num_state_action = np.zeros([env.observation_space.n, env.action_space.n])

# %%
num_episodes = 100000
epsilon = 0.30
rewardsList = []

# %%
for x in range(num_episodes):
    state = env.reset()
    
    done = False
    results_list = []
    result_sum = 0.0
    while not done:
        
        #random action less than epsilon
        if np.random.rand() < epsilon:
            #we go with the random action
            action = env.action_space.sample()
        else:
            # 1 - epsilon probability, we go with the greedy algorithm
            action = np.argmax(Q[state, :])
            
        #action is performed and assigned to new_state, reward   
        new_state, reward, done, info = env.step(action)
        

        results_list.append((state, action))
        result_sum += reward
        
        #new state is assigned as state
        state = new_state
      
    #appending the results sum to the rewards list
    rewardsList.append(result_sum)

    for (state, action) in results_list:
        num_state_action[state, action] += 1.0
        sa_factor = 1.0 / num_state_action[state, action]
        Q[state, action] += sa_factor * (result_sum - Q[state, action])

    if x % 1000 == 0 and x is not 0:
        print('Frozen Lake Success rate=>', str(sum(rewardsList) * 100 / x ), '%')
print("Frozen Lake Success rate=>", str(sum(rewardsList)/num_episodes * 100), "%")
# Out:
# Frozen Lake Success rate=> 34.0 %
# Frozen Lake Success rate=> 51.4 %
# Frozen Lake Success rate=> 56.03333333333333 %
# Frozen Lake Success rate=> 58.575 %
# Frozen Lake Success rate=> 59.44 %
# Frozen Lake Success rate=> 60.11666666666667 %
# Frozen Lake Success rate=> 60.642857142857146 %
# Frozen Lake Success rate=> 61.15 %
# Frozen Lake Success rate=> 61.75555555555555 %
# Frozen Lake Success rate=> 62.15 %
# Frozen Lake Success rate=> 62.627272727272725 %
# Frozen Lake Success rate=> 62.86666666666667 %
# Frozen Lake Success rate=> 63.19230769230769 %
# Frozen Lake Success rate=> 63.378571428571426 %
# Frozen Lake Success rate=> 63.56666666666667 %
# Frozen Lake Success rate=> 63.9125 %
# Frozen Lake Success rate=> 63.970588235294116 %
# Frozen Lake Success rate=> 64.08888888888889 %
# Frozen Lake Success rate=> 64.15263157894736 %
# Frozen Lake Success rate=> 64.365 %
# Frozen Lake Success rate=> 64.4095238095238 %
# Frozen Lake Success rate=> 64.52727272727273 %
# Frozen Lake Success rate=> 64.66956521739131 %
# Frozen Lake Success rate=> 64.7 %
# Frozen Lake Success rate=> 64.744 %
# Frozen Lake Success rate=> 64.76923076923077 %
# Frozen Lake Success rate=> 64.81851851851852 %
# Frozen Lake Success rate=> 64.78214285714286 %
# Frozen Lake Success rate=> 64.96551724137932 %
# Frozen Lake Success rate=> 64.98 %
# Frozen Lake Success rate=> 65.08064516129032 %
# Frozen Lake Success rate=> 65.171875 %
# Frozen Lake Success rate=> 65.23030303030303 %
# Frozen Lake Success rate=> 65.25294117647059 %
# Frozen Lake Success rate=> 65.24571428571429 %
# Frozen Lake Success rate=> 65.24166666666666 %
# Frozen Lake Success rate=> 65.2945945945946 %
# Frozen Lake Success rate=> 65.32368421052631 %
# Frozen Lake Success rate=> 65.28461538461538 %
# Frozen Lake Success rate=> 65.28 %
# Frozen Lake Success rate=> 65.31219512195122 %
# Frozen Lake Success rate=> 65.31190476190476 %
# Frozen Lake Success rate=> 65.30465116279069 %
# Frozen Lake Success rate=> 65.34772727272727 %
# Frozen Lake Success rate=> 65.44666666666667 %
# Frozen Lake Success rate=> 65.48913043478261 %
# Frozen Lake Success rate=> 65.47446808510638 %
# Frozen Lake Success rate=> 65.51875 %
# Frozen Lake Success rate=> 65.5326530612245 %
# Frozen Lake Success rate=> 65.522 %
# Frozen Lake Success rate=> 65.52156862745097 %
# Frozen Lake Success rate=> 65.51538461538462 %
# Frozen Lake Success rate=> 65.5320754716981 %
# Frozen Lake Success rate=> 65.53703703703704 %
# Frozen Lake Success rate=> 65.57454545454546 %
# Frozen Lake Success rate=> 65.60892857142858 %
# Frozen Lake Success rate=> 65.6421052631579 %
# Frozen Lake Success rate=> 65.67413793103448 %
# Frozen Lake Success rate=> 65.70169491525424 %
# Frozen Lake Success rate=> 65.71666666666667 %
# Frozen Lake Success rate=> 65.70655737704918 %
# Frozen Lake Success rate=> 65.71290322580646 %
# Frozen Lake Success rate=> 65.75714285714285 %
# Frozen Lake Success rate=> 65.75625 %
# Frozen Lake Success rate=> 65.73384615384616 %
# Frozen Lake Success rate=> 65.72575757575757 %
# Frozen Lake Success rate=> 65.76119402985074 %
# Frozen Lake Success rate=> 65.8 %
# Frozen Lake Success rate=> 65.80724637681159 %
# Frozen Lake Success rate=> 65.81714285714285 %
# Frozen Lake Success rate=> 65.85774647887324 %
# Frozen Lake Success rate=> 65.87361111111112 %
# Frozen Lake Success rate=> 65.91095890410959 %
# Frozen Lake Success rate=> 65.95 %
# Frozen Lake Success rate=> 65.96933333333334 %
# Frozen Lake Success rate=> 65.99605263157895 %
# Frozen Lake Success rate=> 66.02207792207793 %
# Frozen Lake Success rate=> 65.99743589743589 %
# Frozen Lake Success rate=> 66.00506329113924 %
# Frozen Lake Success rate=> 65.99875 %
# Frozen Lake Success rate=> 65.99876543209876 %
# Frozen Lake Success rate=> 65.99878048780488 %
# Frozen Lake Success rate=> 66.0 %
# Frozen Lake Success rate=> 66.01666666666667 %
# Frozen Lake Success rate=> 66.04470588235294 %
# Frozen Lake Success rate=> 66.03139534883721 %
# Frozen Lake Success rate=> 66.04827586206896 %
# Frozen Lake Success rate=> 66.03068181818182 %
# Frozen Lake Success rate=> 66.03370786516854 %
# Frozen Lake Success rate=> 66.03555555555556 %
# Frozen Lake Success rate=> 66.03406593406594 %
# Frozen Lake Success rate=> 66.03152173913044 %
# Frozen Lake Success rate=> 66.04516129032258 %
# Frozen Lake Success rate=> 66.05425531914894 %
# Frozen Lake Success rate=> 66.07368421052631 %
# Frozen Lake Success rate=> 66.09375 %
# Frozen Lake Success rate=> 66.09484536082475 %
# Frozen Lake Success rate=> 66.08367346938776 %
# Frozen Lake Success rate=> 66.07171717171717 %
# Frozen Lake Success rate=> 66.098 %
