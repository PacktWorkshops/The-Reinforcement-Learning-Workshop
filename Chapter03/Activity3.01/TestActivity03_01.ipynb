# %%
import unittest
import import_ipynb
import pandas as pd
import pandas.testing as pd_testing
import tensorflow as tf

class TestActivity03_01(unittest.TestCase):
    def setUp(self):
        import Activity03_01
        self.exercises = Activity03_01

    def test_accuracy(self):
        self.assertEqual(self.exercises.test_accuracy > 0.85, True)

# %%
suite = unittest.TestLoader().loadTestsFromTestCase(TestActivity03_01)
unittest.TextTestRunner(verbosity=2).run(suite)
# Out:
# test_accuracy (__main__.TestActivity03_01) ...
# importing Jupyter notebook from Activity03_01.ipynb
# TensorFlow version: 2.1.0
# TensorFlow datasets version: 2.1.0
# Eager execution: True
# Training dataset shape = (60000, 28, 28)
# Training labels length = 60000
# Some training labels = [2 1 8 4 1]
# Test dataset shape = (10000, 28, 28)
# Test labels length = 10000
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.5003 - accuracy: 0.8254
# Epoch 2/10
# 60000/60000 [==============================] - 2s 38us/sample - loss: 0.3732 - accuracy: 0.8648
# Epoch 3/10
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.3366 - accuracy: 0.8767
# Epoch 4/10
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.3096 - accuracy: 0.8863
# Epoch 5/10
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.2937 - accuracy: 0.8911
# Epoch 6/10
# ...
