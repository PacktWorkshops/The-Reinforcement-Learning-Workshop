# %%
import unittest
import import_ipynb
import gym

class TestExercise11_01(unittest.TestCase):
    def setUp(self):
        import Exercise11_01
        self.exercises = Exercise11_01
    
    def test_running_reward(self):
        self.assertEqual(self.exercises.running_reward < 0, False)

# %%
suite = unittest.TestLoader().loadTestsFromTestCase(TestExercise11_01)
unittest.TextTestRunner(verbosity=2).run(suite)
# Out:
# test_running_reward (__main__.TestExercise11_01) ... Exercise11_01.ipynb:16: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   "import numpy as np"
# importing Jupyter notebook from Exercise11_01.ipynb
# Episode 0	Reward: -79.72110170480283
# Episode 1	Reward: -468.54759991721403
# Episode 2	Reward: -913.222240286001
# Episode 3	Reward: -967.6722177883332
# Episode 4	Reward: -1453.7440896302132
# Episode 5	Reward: -1512.3223819380457
# Episode 6	Reward: -1693.1692500022498
# Episode 7	Reward: -1850.7989939292193
# Episode 8	Reward: -2055.3363409951257
# Episode 9	Reward: -2328.041089314597
# Episode 10	Reward: -2407.9078570421366
# Episode 11	Reward: -2525.7085399990415
# Episode 12	Reward: -2635.605474720843
# Episode 13	Reward: -2754.287954277804
# Episode 14	Reward: -3070.7052253337883
# Episode 15	Reward: -3159.3053398785396
# Episode 16	Reward: -3248.718519393975
# Episode 17	Reward: -3688.3876265925346
# ...
