# %%
import unittest
import import_ipynb
import gym

class TestExercise11_03(unittest.TestCase):
    def setUp(self):
        import Exercise11_03
        self.exercises = Exercise11_03
    
    def test_current_reward(self):
        self.assertEqual(self.exercises.current_reward > 100, True)

# %%
suite = unittest.TestLoader().loadTestsFromTestCase(TestExercise11_03)
unittest.TextTestRunner(verbosity=2).run(suite)
# Out:
# test_current_reward (__main__.TestExercise11_03) ...
# importing Jupyter notebook from Exercise11_03.ipynb
# Episode 0, reward: -7
# Episode 20, reward: -200
# Episode 40, reward: -118
# Episode 60, reward: -114
# Episode 80, reward: -134
# Episode 100, reward: -112
# Episode 120, reward: -122
# Episode 140, reward: -114
# Episode 160, reward: -113
# Episode 180, reward: -89
# Episode 200, reward: -110
# Episode 220, reward: -77
# Episode 240, reward: -89
# Episode 260, reward: -105
# Episode 280, reward: -65
# Episode 300, reward: -44
# Episode 320, reward: -29
# Episode 340, reward: -31
# Episode 360, reward: -46
# Episode 380, reward: -1
# Episode 400, reward: 7
# Episode 420, reward: 37
# Episode 440, reward: 34
# Episode 460, reward: 27
# Episode 480, reward: 73
# Episode 500, reward: 71
# Episode 520, reward: 87
# Episode 540, reward: 97
# Episode 560, reward: 111
# Episode 580, reward: 107
# Episode 600, reward: 105
# Episode 620, reward: 124
# Episode 640, reward: 108
# ...
