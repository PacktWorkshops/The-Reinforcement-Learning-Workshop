# %%
from baselines.ppo2.ppo2 import learn
from baselines.ppo2 import defaults
from baselines.common.vec_env import VecEnv, VecFrameStack
from baselines.common.cmd_util import make_vec_env, make_env
from baselines.common.models import register
import tensorflow as tf

# %%
@register("custom_mlp")
def custom_mlp(num_layers=2, num_hidden=64, activation=tf.tanh):
    """
    Stack of fully-connected layers to be used in a policy / q-function approximator
    Parameters:
    ----------
    num_layers: int                 number of fully-connected layers (default: 2)
    num_hidden: int                 size of fully-connected layers (default: 64)
    activation:                     activation function (default: tf.tanh)
    Returns:
    -------
    function that builds fully connected network with a given input tensor / placeholder
    """
    def network_fn(input_shape):
        print('input shape is {}'.format(input_shape))
        x_input = tf.keras.Input(shape=input_shape)
        h = x_input
        for i in range(num_layers):
            h = tf.keras.layers.Dense(units=num_hidden, name='custom_mlp_fc{}'.format(i),
                                      activation=activation)(h)

        network = tf.keras.Model(inputs=[x_input], outputs=[h])
        network.summary()
        return network

    return network_fn

# %%
def build_env(env_id, env_type):

    if env_type in {'atari', 'retro'}:
        env = make_vec_env(env_id, env_type, 1, None, gamestate=None, reward_scale=1.0)
        env = VecFrameStack(env, 4)

    else:
        env = make_vec_env(env_id, env_type, 1, None, reward_scale=1.0, flatten_dict_observations=True)

    return env

# %%
env_id = 'CartPole-v0'
env_type = 'classic_control'
print("Env type = ", env_type)

env = build_env(env_id, env_type)

hidden_nodes = 64
hidden_layers = 2

model = learn(network="custom_mlp", env=env, total_timesteps=1e4, num_hidden=hidden_nodes, num_layers=hidden_layers)
# Out:
# Env type =  classic_control
# Logging to /tmp/openai-2020-05-11-16-00-34-432546
# input shape is (4,)
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 4)]               0
# _________________________________________________________________
# custom_mlp_fc0 (Dense)       (None, 64)                320
# _________________________________________________________________
# custom_mlp_fc1 (Dense)       (None, 64)                4160
# =================================================================
# Total params: 4,480
# Trainable params: 4,480
# Non-trainable params: 0
# _________________________________________________________________
# -------------------------------------------
# | eplenmean               | 22.3          |
# | eprewmean               | 22.3          |
# | fps                     | 696           |
# | loss/approxkl           | 0.00013790815 |
# | loss/clipfrac           | 0.0           |
# | loss/policy_entropy     | 0.6929994     |
# | loss/policy_loss        | -0.0029695872 |
# | loss/value_loss         | 44.237858     |
# | misc/explained_variance | 0.0143        |
# | misc/nupdates           | 1             |
# | misc/serial_timesteps   | 2048          |
# | misc/time_elapsed       | 2.94          |
# | misc/total_timesteps    | 2048          |
# -------------------------------------------

# %%
obs = env.reset()
if not isinstance(env, VecEnv):
    obs = np.expand_dims(np.array(obs), axis=0)

episode_rew = 0
    
while True:
    actions, _, state, _ = model.step(obs)
    obs, reward, done, info = env.step(actions.numpy())
    if not isinstance(env, VecEnv):
        obs = np.expand_dims(np.array(obs), axis=0)
    env.render()
    print("Reward = ", reward)
    episode_rew += reward
    
    if done:
        print('Episode Reward = {}'.format(episode_rew))
        break

env.close()
# Out:
# Reward =  [1.]
# Reward =  [1.]
# Reward =  [1.]
# Reward =  [1.]
# Reward =  [1.]
# Reward =  [1.]
# Reward =  [1.]
# Reward =  [1.]
# Reward =  [1.]
# Reward =  [1.]
# Reward =  [1.]
# Reward =  [1.]
# Reward =  [1.]
# Reward =  [1.]
# Reward =  [1.]
# Reward =  [1.]
# Reward =  [1.]
# Reward =  [1.]
# Reward =  [1.]
# Reward =  [1.]
# Reward =  [1.]
# Reward =  [1.]
# Reward =  [1.]
# Reward =  [1.]
# Reward =  [1.]
# Reward =  [1.]
# Reward =  [1.]
# Reward =  [1.]
# Episode Reward = [28.]

# %%
# !python -m baselines.run --alg=ppo2 --env=CartPole-v0 --num_timesteps=1e4 --save_path=./models/CartPole_2M_ppo2 --log_path=./logs/CartPole/
# Out:
# Logging to ./logs/CartPole/
# env_type: classic_control
# Training ppo2 on classic_control:CartPole-v0 with arguments
# {'network': 'mlp'}
# input shape is (4,)
# 2020-05-11 15:55:26.787164: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-11 15:55:26.801169: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-11 15:55:26.801452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1050 Ti computeCapability: 6.1
# coreClock: 1.4175GHz coreCount: 6 deviceMemorySize: 3.94GiB deviceMemoryBandwidth: 104.43GiB/s
# 2020-05-11 15:55:26.801636: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-05-11 15:55:26.803076: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-05-11 15:55:26.804488: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-05-11 15:55:26.804788: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-05-11 15:55:26.806245: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-05-11 15:55:26.807126: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-05-11 15:55:26.810511: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-05-11 15:55:26.810679: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-11 15:55:26.811023: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-11 15:55:26.811232: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# 2020-05-11 15:55:26.811499: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2020-05-11 15:55:26.817508: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3000000000 Hz
# 2020-05-11 15:55:26.817722: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55fa9da3c940 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-05-11 15:55:26.817741: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-05-11 15:55:26.817936: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-11 15:55:26.818186: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1050 Ti computeCapability: 6.1
# coreClock: 1.4175GHz coreCount: 6 deviceMemorySize: 3.94GiB deviceMemoryBandwidth: 104.43GiB/s
# 2020-05-11 15:55:26.818234: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-05-11 15:55:26.818249: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-05-11 15:55:26.818263: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-05-11 15:55:26.818276: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-05-11 15:55:26.818290: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-05-11 15:55:26.818304: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-05-11 15:55:26.818318: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-05-11 15:55:26.818376: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-11 15:55:26.818618: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-11 15:55:26.818818: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# 2020-05-11 15:55:26.818845: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-05-11 15:55:26.859499: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1096] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-05-11 15:55:26.859539: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102]      0
# 2020-05-11 15:55:26.859545: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] 0:   N
# 2020-05-11 15:55:26.859707: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-11 15:55:26.860022: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-11 15:55:26.860288: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-11 15:55:26.860533: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1241] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 3167 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1050 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# 2020-05-11 15:55:26.862040: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55fa9e8c25e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-05-11 15:55:26.862078: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): GeForce GTX 1050 Ti, Compute Capability 6.1
# 2020-05-11 15:55:27.910890: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-05-11 15:55:30.122921: W tensorflow/python/util/util.cc:319] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# -------------------------------------------
# | eplenmean               | 20.8          |
# | eprewmean               | 20.8          |
# | fps                     | 675           |
# | loss/approxkl           | 0.00041882397 |
# | loss/clipfrac           | 0.0           |
# | loss/policy_entropy     | 0.692711      |
# | loss/policy_loss        | -0.004152138  |
# | loss/value_loss         | 42.336742     |
# | misc/explained_variance | -0.0112       |
# | misc/nupdates           | 1             |
# | misc/serial_timesteps   | 2048          |
# | misc/time_elapsed       | 3.03          |
# | misc/total_timesteps    | 2048          |
# -------------------------------------------

# %%
# !python -m baselines.run --alg=ppo2 --env=CartPole-v0 --num_timesteps=0 --load_path=./models/CartPole_2M_ppo2 --play
# Out:
# Logging to /tmp/openai-2020-05-11-15-55-48-346600
# env_type: classic_control
# Training ppo2 on classic_control:CartPole-v0 with arguments
# {'load_path': './models/CartPole_2M_ppo2', 'network': 'mlp'}
# input shape is (4,)
# 2020-05-11 15:55:48.379178: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-11 15:55:48.391881: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-11 15:55:48.392122: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1050 Ti computeCapability: 6.1
# coreClock: 1.4175GHz coreCount: 6 deviceMemorySize: 3.94GiB deviceMemoryBandwidth: 104.43GiB/s
# 2020-05-11 15:55:48.392269: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-05-11 15:55:48.393571: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-05-11 15:55:48.394807: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-05-11 15:55:48.395027: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-05-11 15:55:48.396374: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-05-11 15:55:48.397148: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-05-11 15:55:48.400393: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-05-11 15:55:48.400544: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-11 15:55:48.400827: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-11 15:55:48.401026: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# 2020-05-11 15:55:48.401236: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2020-05-11 15:55:48.406271: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3000000000 Hz
# 2020-05-11 15:55:48.406435: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55a9dc1a07d0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-05-11 15:55:48.406449: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-05-11 15:55:48.406623: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-11 15:55:48.406867: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1050 Ti computeCapability: 6.1
# coreClock: 1.4175GHz coreCount: 6 deviceMemorySize: 3.94GiB deviceMemoryBandwidth: 104.43GiB/s
# 2020-05-11 15:55:48.406910: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-05-11 15:55:48.406926: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-05-11 15:55:48.406939: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-05-11 15:55:48.406952: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-05-11 15:55:48.406966: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-05-11 15:55:48.406981: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-05-11 15:55:48.406996: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-05-11 15:55:48.407052: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-11 15:55:48.407292: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-11 15:55:48.407492: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# 2020-05-11 15:55:48.407520: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-05-11 15:55:48.450212: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1096] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-05-11 15:55:48.450251: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102]      0
# 2020-05-11 15:55:48.450258: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] 0:   N
# 2020-05-11 15:55:48.450418: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-11 15:55:48.450691: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-11 15:55:48.450929: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-11 15:55:48.451141: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1241] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 3167 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1050 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# 2020-05-11 15:55:48.452517: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55a9dd0a6440 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-05-11 15:55:48.452531: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): GeForce GTX 1050 Ti, Compute Capability 6.1
# Running trained model
# 2020-05-11 15:55:49.416749: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
com/PacktWorkshops/The-Reinforcement-Learning-Workshop/blob/master/Chapter04/cartpole_1M_ppo2.tar.gz?raw=true
# Out:
# --2020-05-11 15:57:05--  https://github.com/PacktWorkshops/The-Reinforcement-Learning-Workshop/blob/master/Chapter04/cartpole_1M_ppo2.tar.gz?raw=true
# Resolving github.com (github.com)... 140.82.118.4
# Connecting to github.com (github.com)|140.82.118.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/PacktWorkshops/The-Reinforcement-Learning-Workshop/raw/master/Chapter04/cartpole_1M_ppo2.tar.gz [following]
# --2020-05-11 15:57:06--  https://github.com/PacktWorkshops/The-Reinforcement-Learning-Workshop/raw/master/Chapter04/cartpole_1M_ppo2.tar.gz
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/PacktWorkshops/The-Reinforcement-Learning-Workshop/master/Chapter04/cartpole_1M_ppo2.tar.gz [following]
# --2020-05-11 15:57:06--  https://raw.githubusercontent.com/PacktWorkshops/The-Reinforcement-Learning-Workshop/master/Chapter04/cartpole_1M_ppo2.tar.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.192.133, 151.101.128.133, 151.101.64.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.192.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54633 (53K) [application/octet-stream]
# Saving to: ‘cartpole_1M_ppo2.tar.gz’
#
# cartpole_1M_ppo2.ta 100%[===================>]  53,35K  --.-KB/s    in 0,05s
#
# 2020-05-11 15:57:07 (1,10 MB/s) - ‘cartpole_1M_ppo2.tar.gz’ saved [54633/54633]

# %%
# !tar xvzf cartpole_1M_ppo2.tar.gz
# Out:
# cartpole_1M_ppo2/ckpt-1.index
# cartpole_1M_ppo2/ckpt-1.data-00000-of-00001
# cartpole_1M_ppo2/
# cartpole_1M_ppo2/checkpoint

# %%
# !python -m baselines.run --alg=ppo2 --env=CartPole-v0 --num_timesteps=0 --load_path=./cartpole_1M_ppo2 --play
# Out:
# Logging to /tmp/openai-2020-05-11-15-57-10-692773
# env_type: classic_control
# Training ppo2 on classic_control:CartPole-v0 with arguments
# {'load_path': './cartpole_1M_ppo2', 'network': 'mlp'}
# input shape is (4,)
# 2020-05-11 15:57:10.727104: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-11 15:57:10.739807: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-11 15:57:10.740048: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1050 Ti computeCapability: 6.1
# coreClock: 1.4175GHz coreCount: 6 deviceMemorySize: 3.94GiB deviceMemoryBandwidth: 104.43GiB/s
# 2020-05-11 15:57:10.740203: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-05-11 15:57:10.741537: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-05-11 15:57:10.742831: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-05-11 15:57:10.743093: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-05-11 15:57:10.744436: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-05-11 15:57:10.745216: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-05-11 15:57:10.748152: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-05-11 15:57:10.748306: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-11 15:57:10.748618: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-11 15:57:10.748845: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# 2020-05-11 15:57:10.749080: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2020-05-11 15:57:10.754548: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3000000000 Hz
# 2020-05-11 15:57:10.754803: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x561659a59fa0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-05-11 15:57:10.754821: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-05-11 15:57:10.754999: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-11 15:57:10.755248: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1050 Ti computeCapability: 6.1
# coreClock: 1.4175GHz coreCount: 6 deviceMemorySize: 3.94GiB deviceMemoryBandwidth: 104.43GiB/s
# 2020-05-11 15:57:10.755304: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-05-11 15:57:10.755319: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-05-11 15:57:10.755332: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-05-11 15:57:10.755346: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-05-11 15:57:10.755359: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-05-11 15:57:10.755372: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-05-11 15:57:10.755386: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-05-11 15:57:10.755441: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-11 15:57:10.755676: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-11 15:57:10.755870: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# 2020-05-11 15:57:10.755897: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-05-11 15:57:10.799295: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1096] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-05-11 15:57:10.799320: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102]      0
# 2020-05-11 15:57:10.799327: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] 0:   N
# 2020-05-11 15:57:10.799501: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-11 15:57:10.799808: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-11 15:57:10.800074: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-11 15:57:10.800314: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1241] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 3164 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1050 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# 2020-05-11 15:57:10.801779: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x56165a9a8680 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-05-11 15:57:10.801812: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): GeForce GTX 1050 Ti, Compute Capability 6.1
# Running trained model
# 2020-05-11 15:57:11.773507: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# episode_rew=16.0
# episode_rew=200.0
# episode_rew=200.0
# episode_rew=200.0
# episode_rew=26.0
# episode_rew=176.0
