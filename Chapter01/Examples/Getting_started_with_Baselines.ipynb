# %%
# ! convert -delay X gym-results/openaigym.video.0.5889.video000000.mp4 -loop 0 cartpole.gif

# %% [markdown]
# <img src="gif/cartpole.gif" alt="CartPole" style="width: 500px;"/>

# %%
! python -m baselines.run --alg=deepq --env=CartPole-v0 --save_path=./cartpole_model.pkl --num_timesteps=1e5
# Out:
# Logging to /var/folders/yq/3ns6lnvj3670mmd5kk_dlljm0000gn/T/openai-2020-05-01-15-36-18-955327
# env_type: classic_control
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/run.py:106: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/common/tf_util.py:53: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/common/tf_util.py:70: The name tf.InteractiveSession is deprecated. Please use tf.compat.v1.InteractiveSession instead.
#
# 2020-05-01 15:36:20.615649: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-05-01 15:36:20.637248: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fd3ec8ddbf0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-05-01 15:36:20.637271: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/common/misc_util.py:58: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# Training deepq on classic_control:CartPole-v0 with arguments
# {'network': 'mlp'}
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/deepq/deepq.py:205: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/deepq/build_graph.py:176: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/common/input.py:31: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/common/input.py:57: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/deepq/build_graph.py:181: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/common/models.py:94: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/venvs/rl-book/lib/python3.6/site-packages/tensorflow_core/python/layers/core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/deepq/build_graph.py:187: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/deepq/build_graph.py:189: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/deepq/build_graph.py:389: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/deepq/build_graph.py:389: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/deepq/build_graph.py:389: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/common/tf_util.py:89: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/common/tf_util.py:90: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# /Users/emanueleghelfi/Development/venvs/rl-book/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/emanueleghelfi/Development/venvs/rl-book/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# --------------------------------------
# | % time spent exploring  | 79       |
# | episodes                | 100      |
# | mean 100 episode reward | 21       |
# | steps                   | 2.08e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 45       |
# | episodes                | 200      |
# | mean 100 episode reward | 34.7     |
# | steps                   | 5.56e+03 |
# --------------------------------------
# Saving model due to mean reward increase: None -> 63.900001525878906
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 300      |
# | mean 100 episode reward | 93.8     |
# | steps                   | 1.49e+04 |
# --------------------------------------
# Saving model due to mean reward increase: 63.900001525878906 -> 118.9000015258789
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 400      |
# | mean 100 episode reward | 116      |
# | steps                   | 2.65e+04 |
# --------------------------------------
# Saving model due to mean reward increase: 118.9000015258789 -> 120.30000305175781
# Saving model due to mean reward increase: 120.30000305175781 -> 143.6999969482422
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 500      |
# | mean 100 episode reward | 148      |
# | steps                   | 4.14e+04 |
# --------------------------------------
# Saving model due to mean reward increase: 143.6999969482422 -> 153.6999969482422
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 600      |
# | mean 100 episode reward | 170      |
# | steps                   | 5.84e+04 |
# --------------------------------------
# Saving model due to mean reward increase: 153.6999969482422 -> 170.1999969482422
# Saving model due to mean reward increase: 170.1999969482422 -> 189.6999969482422
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 700      |
# | mean 100 episode reward | 200      |
# | steps                   | 7.84e+04 |
# --------------------------------------
# Saving model due to mean reward increase: 189.6999969482422 -> 200.0
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 800      |
# | mean 100 episode reward | 150      |
# | steps                   | 9.34e+04 |
# --------------------------------------
# Restored model with mean reward: 200.0

# %%
# Load the model saved in cartpole_model.pkl and visualize the learned policy
! python -m baselines.run --alg=deepq --env=CartPole-v0 --load_path=./cartpole_model.pkl --num_timesteps=0 --play

# %%
import gym

# Import the desired algorithm from baselines
from baselines import deepq
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
def callback(locals, globals):
    """
    function called at every step with state of the algorithm.
    If callback returns true training stops.
    """
    # stop training if average reward exceeds 199
    # time should be greater than 100 and the average of last 100 returns should be >= 199
    is_solved = (
        locals["t"] > 100 and sum(locals["episode_rewards"][-101:-1]) / 100 >= 199
    )
    return is_solved

# %%
# create the environment
env = gym.make("CartPole-v0")

# Prepare learning parameters: network and learning rate
# the policy is a multi-layer perceptron
network = "mlp"
# set learning rate of the algorithm
learning_rate = 1e-3

# %%
# launch learning on this environment using DQN
# ignore the exploration parameter for now
actor = deepq.learn(
    env,
    network=network,
    lr=learning_rate,
    total_timesteps=1e5,
    buffer_size=5e4,
    exploration_fraction=0.1,
    exploration_final_eps=0.02,
    print_freq=10,
    callback=callback,
)
# Out:
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/common/tf_util.py:53: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/common/tf_util.py:63: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/common/tf_util.py:70: The name tf.InteractiveSession is deprecated. Please use tf.compat.v1.InteractiveSession instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/common/misc_util.py:58: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/deepq/deepq.py:205: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/deepq/build_graph.py:176: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/common/input.py:31: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/common/input.py:57: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/deepq/build_graph.py:181: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/common/models.py:94: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/venvs/rl-book/lib/python3.6/site-packages/tensorflow_core/python/layers/core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/deepq/build_graph.py:187: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/deepq/build_graph.py:189: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/deepq/build_graph.py:389: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/deepq/build_graph.py:389: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/deepq/build_graph.py:389: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/common/tf_util.py:89: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/common/tf_util.py:90: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# Logging to /var/folders/yq/3ns6lnvj3670mmd5kk_dlljm0000gn/T/openai-2020-05-01-15-53-15-333494
# --------------------------------------
# | % time spent exploring  | 97       |
# | episodes                | 10       |
# | mean 100 episode reward | 24.4     |
# | steps                   | 219      |
# --------------------------------------
# /Users/emanueleghelfi/Development/venvs/rl-book/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/emanueleghelfi/Development/venvs/rl-book/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# --------------------------------------
# | % time spent exploring  | 96       |
# | episodes                | 20       |
# | mean 100 episode reward | 21.3     |
# | steps                   | 403      |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 94       |
# | episodes                | 30       |
# | mean 100 episode reward | 20.4     |
# | steps                   | 590      |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 92       |
# | episodes                | 40       |
# | mean 100 episode reward | 20.7     |
# | steps                   | 805      |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 90       |
# | episodes                | 50       |
# | mean 100 episode reward | 20       |
# | steps                   | 980      |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 88       |
# | episodes                | 60       |
# | mean 100 episode reward | 19.8     |
# | steps                   | 1.17e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 85       |
# | episodes                | 70       |
# | mean 100 episode reward | 21.3     |
# | steps                   | 1.47e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 83       |
# | episodes                | 80       |
# | mean 100 episode reward | 21.2     |
# | steps                   | 1.67e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 80       |
# | episodes                | 90       |
# | mean 100 episode reward | 22       |
# | steps                   | 1.96e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 78       |
# | episodes                | 100      |
# | mean 100 episode reward | 21.8     |
# | steps                   | 2.16e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 76       |
# | episodes                | 110      |
# | mean 100 episode reward | 21.9     |
# | steps                   | 2.41e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 74       |
# | episodes                | 120      |
# | mean 100 episode reward | 22.1     |
# | steps                   | 2.61e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 71       |
# | episodes                | 130      |
# | mean 100 episode reward | 22.7     |
# | steps                   | 2.86e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 70       |
# | episodes                | 140      |
# | mean 100 episode reward | 22.4     |
# | steps                   | 3.05e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 64       |
# | episodes                | 150      |
# | mean 100 episode reward | 26.6     |
# | steps                   | 3.64e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 58       |
# | episodes                | 160      |
# | mean 100 episode reward | 30.2     |
# | steps                   | 4.19e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 51       |
# | episodes                | 170      |
# | mean 100 episode reward | 34.6     |
# | steps                   | 4.94e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 45       |
# | episodes                | 180      |
# | mean 100 episode reward | 38.5     |
# | steps                   | 5.52e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 35       |
# | episodes                | 190      |
# | mean 100 episode reward | 46.1     |
# | steps                   | 6.56e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 24       |
# | episodes                | 200      |
# | mean 100 episode reward | 55.1     |
# | steps                   | 7.66e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 17       |
# | episodes                | 210      |
# | mean 100 episode reward | 60.2     |
# | steps                   | 8.44e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 7        |
# | episodes                | 220      |
# | mean 100 episode reward | 67.8     |
# | steps                   | 9.39e+03 |
# --------------------------------------
# Saving model due to mean reward increase: None -> 72.2
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 230      |
# | mean 100 episode reward | 79.6     |
# | steps                   | 1.08e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 240      |
# | mean 100 episode reward | 93.2     |
# | steps                   | 1.24e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 250      |
# | mean 100 episode reward | 95.6     |
# | steps                   | 1.32e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 260      |
# | mean 100 episode reward | 101      |
# | steps                   | 1.43e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 270      |
# | mean 100 episode reward | 112      |
# | steps                   | 1.61e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 280      |
# | mean 100 episode reward | 118      |
# | steps                   | 1.73e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 290      |
# | mean 100 episode reward | 116      |
# | steps                   | 1.82e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 300      |
# | mean 100 episode reward | 120      |
# | steps                   | 1.97e+04 |
# --------------------------------------
# Saving model due to mean reward increase: 72.2 -> 119.8
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 310      |
# | mean 100 episode reward | 124      |
# | steps                   | 2.09e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 320      |
# | mean 100 episode reward | 129      |
# | steps                   | 2.22e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 330      |
# | mean 100 episode reward | 127      |
# | steps                   | 2.35e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 340      |
# | mean 100 episode reward | 127      |
# | steps                   | 2.51e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 350      |
# | mean 100 episode reward | 130      |
# | steps                   | 2.61e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 360      |
# | mean 100 episode reward | 132      |
# | steps                   | 2.75e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 370      |
# | mean 100 episode reward | 123      |
# | steps                   | 2.84e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 380      |
# | mean 100 episode reward | 115      |
# | steps                   | 2.88e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 390      |
# | mean 100 episode reward | 108      |
# | steps                   | 2.9e+04  |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 400      |
# | mean 100 episode reward | 95.6     |
# | steps                   | 2.92e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 410      |
# | mean 100 episode reward | 85.4     |
# | steps                   | 2.94e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 420      |
# | mean 100 episode reward | 73.3     |
# | steps                   | 2.96e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 430      |
# | mean 100 episode reward | 67.6     |
# | steps                   | 3.03e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 440      |
# | mean 100 episode reward | 61       |
# | steps                   | 3.12e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 450      |
# | mean 100 episode reward | 61.7     |
# | steps                   | 3.23e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 460      |
# | mean 100 episode reward | 66.3     |
# | steps                   | 3.42e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 470      |
# | mean 100 episode reward | 73.5     |
# | steps                   | 3.57e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 480      |
# | mean 100 episode reward | 80       |
# | steps                   | 3.68e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 490      |
# | mean 100 episode reward | 83.7     |
# | steps                   | 3.74e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 500      |
# | mean 100 episode reward | 86.1     |
# | steps                   | 3.78e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 510      |
# | mean 100 episode reward | 94.4     |
# | steps                   | 3.88e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 520      |
# | mean 100 episode reward | 104      |
# | steps                   | 4e+04    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 530      |
# | mean 100 episode reward | 107      |
# | steps                   | 4.1e+04  |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 540      |
# | mean 100 episode reward | 107      |
# | steps                   | 4.19e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 550      |
# | mean 100 episode reward | 110      |
# | steps                   | 4.34e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 560      |
# | mean 100 episode reward | 109      |
# | steps                   | 4.51e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 570      |
# | mean 100 episode reward | 111      |
# | steps                   | 4.68e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 580      |
# | mean 100 episode reward | 120      |
# | steps                   | 4.88e+04 |
# --------------------------------------
# Saving model due to mean reward increase: 119.8 -> 127.3
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 590      |
# | mean 100 episode reward | 131      |
# | steps                   | 5.05e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 600      |
# | mean 100 episode reward | 133      |
# | steps                   | 5.11e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 610      |
# | mean 100 episode reward | 125      |
# | steps                   | 5.13e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 620      |
# | mean 100 episode reward | 116      |
# | steps                   | 5.16e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 630      |
# | mean 100 episode reward | 108      |
# | steps                   | 5.18e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 640      |
# | mean 100 episode reward | 100      |
# | steps                   | 5.19e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 650      |
# | mean 100 episode reward | 94.7     |
# | steps                   | 5.28e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 660      |
# | mean 100 episode reward | 95.9     |
# | steps                   | 5.47e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 670      |
# | mean 100 episode reward | 98.7     |
# | steps                   | 5.67e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 680      |
# | mean 100 episode reward | 92.8     |
# | steps                   | 5.81e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 690      |
# | mean 100 episode reward | 79.3     |
# | steps                   | 5.84e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 700      |
# | mean 100 episode reward | 82.5     |
# | steps                   | 5.94e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 710      |
# | mean 100 episode reward | 82.8     |
# | steps                   | 5.96e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 720      |
# | mean 100 episode reward | 81.3     |
# | steps                   | 5.98e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 730      |
# | mean 100 episode reward | 83.3     |
# | steps                   | 6.01e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 740      |
# | mean 100 episode reward | 83.4     |
# | steps                   | 6.03e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 750      |
# | mean 100 episode reward | 76.1     |
# | steps                   | 6.05e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 760      |
# | mean 100 episode reward | 74.4     |
# | steps                   | 6.21e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 770      |
# | mean 100 episode reward | 74.4     |
# | steps                   | 6.41e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 780      |
# | mean 100 episode reward | 80.3     |
# | steps                   | 6.61e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 790      |
# | mean 100 episode reward | 96.6     |
# | steps                   | 6.81e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 800      |
# | mean 100 episode reward | 106      |
# | steps                   | 7e+04    |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 810      |
# | mean 100 episode reward | 120      |
# | steps                   | 7.16e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 820      |
# | mean 100 episode reward | 139      |
# | steps                   | 7.36e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 830      |
# | mean 100 episode reward | 155      |
# | steps                   | 7.56e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 840      |
# | mean 100 episode reward | 173      |
# | steps                   | 7.76e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 850      |
# | mean 100 episode reward | 188      |
# | steps                   | 7.93e+04 |
# --------------------------------------
# Saving model due to mean reward increase: 127.3 -> 190.0
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 860      |
# | mean 100 episode reward | 189      |
# | steps                   | 8.1e+04  |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 870      |
# | mean 100 episode reward | 189      |
# | steps                   | 8.3e+04  |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 880      |
# | mean 100 episode reward | 189      |
# | steps                   | 8.5e+04  |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 890      |
# | mean 100 episode reward | 189      |
# | steps                   | 8.7e+04  |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 900      |
# | mean 100 episode reward | 189      |
# | steps                   | 8.9e+04  |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 910      |
# | mean 100 episode reward | 187      |
# | steps                   | 9.03e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 920      |
# | mean 100 episode reward | 186      |
# | steps                   | 9.22e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 930      |
# | mean 100 episode reward | 185      |
# | steps                   | 9.41e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 940      |
# | mean 100 episode reward | 183      |
# | steps                   | 9.59e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 950      |
# | mean 100 episode reward | 185      |
# | steps                   | 9.78e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 960      |
# | mean 100 episode reward | 185      |
# | steps                   | 9.95e+04 |
# --------------------------------------
# Restored model with mean reward: 190.0

# %%
print("Saving model to cartpole_model.pkl")
actor.save("cartpole_model.pkl")
# Out:
# Saving model to cartpole_model.pkl

# %%
actor = deepq.learn(
    env,
    network=network,
    lr=learning_rate,
    total_timesteps=0,
    buffer_size=0,
    exploration_fraction=0.1,
    exploration_final_eps=0.02,
    print_freq=10,
    callback=callback,
    load_path="cartpole_model.pkl"
)
# Out:
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/common/tf_util.py:53: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/common/tf_util.py:63: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/common/tf_util.py:70: The name tf.InteractiveSession is deprecated. Please use tf.compat.v1.InteractiveSession instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/common/misc_util.py:58: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/deepq/deepq.py:205: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/deepq/build_graph.py:176: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/common/input.py:31: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/common/input.py:57: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/deepq/build_graph.py:181: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/common/models.py:94: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/venvs/rl-book/lib/python3.6/site-packages/tensorflow_core/python/layers/core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/deepq/build_graph.py:187: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/deepq/build_graph.py:189: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/deepq/build_graph.py:389: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/deepq/build_graph.py:389: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/deepq/build_graph.py:389: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/common/tf_util.py:89: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /Users/emanueleghelfi/Development/rlex/libs/baselines/baselines/common/tf_util.py:90: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# Logging to /var/folders/yq/3ns6lnvj3670mmd5kk_dlljm0000gn/T/openai-2020-05-01-16-30-52-632828
# Loaded model from cartpole_model.pkl

# %%
# Needed to show the environment in a notebook
from gym import wrappers

# %%
env = wrappers.Monitor(
    env, "./gym-results", force=True, video_callable=lambda episode_id: True
)

#visualize the policy
n_episodes = 5
n_timesteps = 1000
for episode in range(n_episodes):
    observation = env.reset()
    episode_return = 0
    for timestep in range(n_timesteps):
        # render the environment
        env.render()

        # select the action according to the actor
        action = actor(observation[None])[0]

        # call env.step function
        observation, reward, done, _ = env.step(action)

        # since the reward is undiscounted we can simply add the reward to the cumulated return
        episode_return += reward

        if done:
            break
    
    # here an episode is terminated, print the return and the number of steps
    print(f"Episode return {episode_return}, Number of steps: {timestep}")
env.close()
# Out:
# Episode return 200.0, Number of steps: 199
# Episode return 200.0, Number of steps: 199
# Episode return 200.0, Number of steps: 199
# Episode return 200.0, Number of steps: 199
# Episode return 200.0, Number of steps: 199

# %%
# Render the episodes
import io
import base64
from IPython.display import HTML, display

def render(episodes_to_watch=1):
    for episode in range(episodes_to_watch):
        video = io.open(
            f"./gym-results/openaigym.video.{env.file_infix}.video{episode:06d}.mp4", "r+b"
        ).read()
        encoded = base64.b64encode(video)
        display(
            HTML(
                data="""
            <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,{0}" type="video/mp4" /></video>""".format(
                    encoded.decode("ascii")
                )
            )
        )

# %%
render(5)
# Out:
#             <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video>
#             <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video>
#             <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video>
#             <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video>
#             <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video>
