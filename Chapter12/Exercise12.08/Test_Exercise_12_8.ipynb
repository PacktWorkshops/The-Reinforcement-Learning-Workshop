# %%
import unittest
import import_ipynb
import numpy as np

class TestExercise12_8(unittest.TestCase):
    def setUp(self):
        import Exercise_12_8
        self.exercises = Exercise_12_8
    
    def test_fitness_function(self):
        population = self.exercises.pop
        fitness = population.run(self.exercises.fitness_function, 10).fitness
        self.assertEqual(round(fitness), 4)

# %%
suite = unittest.TestLoader().loadTestsFromTestCase(TestExercise12_8)
unittest.TextTestRunner(verbosity=2).run(suite)
# Out:
# test_fitness_function (__main__.TestExercise12_8) ...
# importing Jupyter notebook from Exercise_12_8.ipynb
# Output of file configuration: <neat.config.Config object at 0x0000015C7EFEE588>
#
#  ****** Running generation 0 ******
#
# Population's average fitness: 2.41417 stdev: 0.36975
# Best fitness: 2.98802 - size: (1, 2) - species 1 - id 178
# Average adjusted fitness: 0.562
# Mean genetic distance 0.959, standard deviation 0.404
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0   200      3.0    0.562     0
# Total extinctions: 0
# Generation time: 0.020 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: 2.42045 stdev: 0.30679
# Best fitness: 2.99918 - size: (1, 2) - species 1 - id 275
# Average adjusted fitness: 0.502
# Mean genetic distance 1.090, standard deviation 0.432
# Population of 200 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
# ...
